# %% [raw]
# 16/02/26

# %%
#Basic Python

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
v=5
v
# Out:
# 5

# %%
5=v
# Out:
#   Cell In[3], line 1
#     5=v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
5v = 6
5v
# Out:
#   Cell In[4], line 1
#     5v = 6
#     ^
# SyntaxError: invalid decimal literal

# %%
v5 = 10
v5
# Out:
# 10

# %%
v5 = _
v5
# Out:
# 10

# %%
x_train = 80
x_train
# Out:
# 80

# %%
x_y = 20
x_y
# Out:
# 20

# %%
Nit = 7
Nit
# Out:
# 7

# %% [raw]
# 17/02/26 | 18/02/26

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
For = 90
For
# Out:
# 90

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
i = 90
i
# Out:
# 90

# %%
f3 = 2e1
f3
# Out:
# 20.0

# %%
id(i)
# Out:
# 140726482415304

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
print (3+2)
print (3-2)
print (3*2)
print (3/2)
print (3**2)
print (3%2)
print (3//2)
# Out:
# 5
# 1
# 6
# 1.5
# 9
# 1
# 1

# %%
print(type(10.90))
# Out:
# <class 'float'>

# %%
print(type(10))                  # Int
print(type(3.14))                # Float
print(type(1 + 3j))              # Complex
print(type('Linkan Sahu'))   # String
print(type([1, 2, 3]))           # List
print(type({'name':'Linkan'})) # Dictionary
print(type({9.8, 3.14, 2.7}))    # Set
print(type((9.8, 3.14, 2.7)))    # Tuple
print(type(3 == 3))              # Bool
print(type(3 >= 3))              # Bool
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
# <class 'tuple'>
# <class 'bool'>
# <class 'bool'>

# %%
# Variables in Python

first_name = 'Linkan'
last_name = 'Sahu'
country = 'CAP'
city = 'ODISHA'
age = 24
is_married = False
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Asabeneh', 
    'lastname':'Yetayeh', 
    'country':'Finland',
    'city':'Helsinki'
    }

# Printing the values stored in the variables

print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)
# Out:
# First name: Linkan
# First name length: 6
# Last name:  Sahu
# Last name length:  4
# Country:  CAP
# City:  ODISHA
# Age:  24
# Married:  False
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']
# Person information:  {'firstname': 'Asabeneh', 'lastname': 'Yetayeh', 'country': 'Finland', 'city': 'Helsinki'}

# %%
# Declaring multiple variables in one line

first_name, last_name, country, age, is_married = 'Linkan', 'Sahu', 'Helsink', 24, False

print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# Linkan Sahu Helsink 24 False
# First name: Linkan
# Last name:  Sahu
# Country:  Helsink
# Age:  24
# Married:  False

# %%
First_Name = 'Linkan'
Last_Name = 'Sahu'
Age = 24
Address = 'Ganjam'
print('Person info :-')
print('First Name:-',First_Name)
print('First Name Length:-',len(First_Name))
print('Last Name:-',Last_Name)
print('Last Name Length:-',len(Last_Name))
print('Age:-',Age)
print('Address:-',Address)
# Out:
# Person info :-
# First Name:- Linkan
# First Name Length:- 6
# Last Name:- Sahu
# Last Name Length:- 4
# Age:- 24
# Address:- Ganjam

# %%
first_Name, Last_Name, Age, Address = 'Linkan', 'Sahu', '24', 'Ganjam'
print('Full Name:-', first_Name, Last_Name,'Age:-', Age,'Address:-', Address)
# Out:
# Full Name:- Linkan Sahu Age:- 24 Address:- Ganjam

# %% [raw]
# 19/02/26

# %% [markdown]
# TYPE CASTING

# %%
#Float to int
int(20.78)
# Out:
# 20

# %%
int( 23.0, 34.90 ) #Error beacause by default only 1 agrument is allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int( 23.0, 34.90 )
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
#bool to int
print(int (True))
print(int (False))
# Out:
# 1
# 0

# %%
#Complex to int 
int(10+4j) #Error because Type casting is impossible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Complex to int
# ----> 2 int(10+4j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
#String to int
int(10)
# Out:
# 10

# %%
int('Ten') #Error because Text string is impossible in Type Casting only Number string is possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('Ten')
#
# ValueError: invalid literal for int() with base 10: 'Ten'

# %%
Other Data Type to Float Type Conversion

# %%
#int to Float
float(90)
# Out:
# 90.0

# %%
#bool to Float
print(float(True))
print(float(False))
# Out:
# 1.0
# 0.0

# %%
#complex to float
float(30+40j) #Type Casting is impossible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 #complex to float
# ----> 2 float(30+40j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
#string to float
float('90') # Number string is possible, Text string is not possible
# Out:
# 90.0

# %%
Other Data Type to Complex Type Conversion

# %%
#int to complex
complex(80)
# Out:
# (80+0j)

# %%
complex(78,56)
# Out:
# (78+56j)

# %%
complex(78,90,65) # Error because in this only 2 arguments are allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 complex(78,90,65)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
#float to complex
complex(238.9,56.99)
# Out:
# (238.9+56.99j)

# %%
#bool to complex
print(complex(True))
print(complex(False))
print(complex(True,True))
print(complex(False,True))
# Out:
# (1+0j)
# 0j
# (1+1j)
# 1j

# %%
#string to complex
complex('45')
# Out:
# (45+0j)

# %%
complex('45','56') # Error because only 1 no. string is possible 2 no. string is not possible and 
                    #Text string is also not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex('45','56')
#
# TypeError: complex() can't take second arg if first is a string

# %% [raw]
# 23/02/26

# %% [markdown]
# Other datatype to bool

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
bool(%)
# Out:
#   Cell In[4], line 1
#     bool(%)
#          ^
# SyntaxError: invalid syntax

# %%
bool(1.3)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0.1)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(2+)
# Out:
#   Cell In[3], line 1
#     bool(2+)
#            ^
# SyntaxError: invalid syntax

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool('zero')
# Out:
# True

# %% [markdown]
# other datatype to string

# %%
str(1)
# Out:
# '1'

# %%
str(24)
# Out:
# '24'

# %%
str(2.897)
# Out:
# '2.897'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# Python operator

# %% [raw]
# Arithmetic Operator

# %%
x, y = 10, 5
x, y
# Out:
# (10, 5)

# %%
x+y
# Out:
# 15

# %%
x-y
# Out:
# 5

# %%
x*y
# Out:
# 50

# %%
x/y
# Out:
# 2.0

# %%
x//y
# Out:
# 2

# %%
x%y
# Out:
# 0

# %%
x1=3
y1=3
x1**y1
# Out:
# 27

# %% [raw]
# Assignment operator

# %%
x = 2
x
# Out:
# 2

# %%
x = x+2
x
# Out:
# 4

# %%
x +=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 12

# %%
x-=2

# %%
x
# Out:
# 10

# %%
x/=2
x
# Out:
# 5.0

# %%
x=10
x//=2
x
# Out:
# 5

# %%
x=10
x%=2
x
# Out:
# 0

# %% [raw]
# Relational Operator

# %%
a=5
b=6
print('a','b')
# Out:
# a b

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a==b
# Out:
# False

# %% [raw]
# Unary operator

# %%
n = 4
n
# Out:
# 4

# %%
m = -(n)
m
# Out:
# -4

# %%
n
# Out:
# 4

# %%
-n
# Out:
# -4

# %% [raw]
# Logical operator

# %%
a = 5
b = 4
print('a','b')
# Out:
# a b

# %%
a<8 and b<5
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
a<8 or b<2
# Out:
# True

# %%
x = False
x
# Out:
# False

# %%
x = not x
x
# Out:
# True

# %% [markdown]
# String indexing

# %%
s5 = 'Welcome'
s5
# Out:
# 'Welcome'

# %%
s5[0]
# Out:
# 'W'

# %%
s5[5]
# Out:
# 'm'

# %%
s5[-5]
# Out:
# 'l'

# %%
s5[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 s5[7]
#
# IndexError: string index out of range

# %% [raw]
# 24/02/26

# %% [markdown]
# Python indexing and slicing

# %%
s1 = 'Welcometeam'
s1
# Out:
# 'Welcometeam'

# %%
type(s1)
# Out:
# str

# %%
len(s1)
# Out:
# 11

# %%
s1
# Out:
# 'Welcometeam'

# %%
s1[1] #forward index
# Out:
# 'e'

# %%
s1[-2] #Backward index
# Out:
# 'a'

# %% [markdown]
# slicing

# %%
s1
# Out:
# 'Welcometeam'

# %%
s1[:]
# Out:
# 'Welcometeam'

# %%
s1[7:11]
# Out:
# 'team'

# %%
s1[7:]
# Out:
# 'team'

# %%
s1[2:10]
# Out:
# 'lcometea'

# %%
s1[:10]
# Out:
# 'Welcometea'

# %%
s1[4:]
# Out:
# 'ometeam'

# %%
s1[12:]
# Out:
# ''

# %%
s1[:50]
# Out:
# 'Welcometeam'

# %%
s1[13:50]
# Out:
# ''

# %%
s1
# Out:
# 'Welcometeam'

# %%
s1[1:8:2]
# Out:
# 'ecmt'

# %%
 s1[1:10:3]#forward slicing
# Out:
# 'eot'

# %%
s1[::3]#step slicing
# Out:
# 'Wcea'

# %%
s1[-9:-1:3]#Backward slicing
# Out:
# 'lme'

# %%
s1[::-1]
# Out:
# 'maetemocleW'

# %%
s1[::-2]
# Out:
# 'meeolW'

# %%
s1[::1]
# Out:
# 'Welcometeam'

# %% [raw]
# 25/02/26

# %% [markdown]
# NUMBER SYSTEM

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(0)
# Out:
# '0x0'

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(18)
# Out:
# '0x12'

# %%
int(0x12)
# Out:
# 18

# %% [markdown]
# BITWISE OPERATOR

# %% [raw]
# Complement ~

# %%
~12
# Out:
# -13

# %%
~456
# Out:
# -457

# %% [raw]
# and &

# %%
12 & 13
# Out:
# 12

# %% [raw]
# or |

# %%
12 | 13
# Out:
# 13

# %% [raw]
# xor ^

# %%
12 ^ 13
# Out:
# 1

# %% [raw]
# left side<<

# %%
12<<2
# Out:
# 48

# %% [raw]
# right side>>

# %%
12>>3
# Out:
# 1

# %%
12>>2
# Out:
# 3

# %%
bin(15)
# Out:
# '0b1111'

# %%
15>>2
# Out:
# 3

# %% [raw]
# 26/02/2026

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
pi = 4.17
pi
# Out:
# 4.17

# %%
math.floor(3.23)
# Out:
# 3

# %%
math.ceil(3.23)
# Out:
# 4

# %%
m.pow(3,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 m.pow(3,2)
#
# NameError: name 'm' is not defined

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
import math as m
m.pow(3,2)
# Out:
# 9.0

# %%
import math as m
round(m.pow(3,2))
# Out:
# 9

# %%
import math as m
print(m.pow(3,2))
print(m.floor(3.3))
print(m.ceil(3.3))
# Out:
# 9.0
# 3
# 4

# %%
from math import sqrt,pow,floor,ceil
print(pow(2,3))
print(sqrt(10))
print(floor(3.2))
print(ceil(3.2))
# Out:
# 8.0
# 3.1622776601683795
# 3
# 4

# %%
from math import *
print(pow(2,3))
print(sqrt(10))
print(floor(3.2))
print(ceil(3.2))
# Out:
# 8.0
# 3.1622776601683795
# 3
# 4

# %% [raw]
# input()

# %%
x = input()
x
# Out:
#  Hii Linkan Welcome to the Class
# 'Hii Linkan Welcome to the Class'

# %%
x = input()
y = input()
print(x)
print(y)
# Out:
#  Hii Linkan
#  Welcome to the Class
# Hii Linkan
# Welcome to the Class

# %%
x1 = input()
y1 = input()
z1 = x1+y1
print(z1)
# Out:
#  90
#  90
# 9090

# %%
x = int(input())
y = int(input())
z = x+y
print(z)
# Out:
#  70
#  60
# 130

# %%
type(x)
# Out:
# int

# %%
type(x1)
# Out:
# str

# %%
a = int(input('1st No.'))
b = int(input('2nd No.'))
c = a+b
print(c)
# Out:
# 1st No. 50
# 2nd No. 50
# 100

# %%
a1 = (input('user_name'))
b1 = (input('Password'))
c1 = a1 + b1
print(c1)
# Out:
# user_name linkan
# Password  1234
# linkan 1234

# %%
s = input('Enter a string')
print(s)
# Out:
# Enter a string Welcome
# Welcome

# %%
print(s[1])
# Out:
# e

# %%
s = input('Enter a string')
print(s[4])
# Out:
# Enter a string Welcome
# o

# %%
s = input('Enter a string')[3]
print(s)
# Out:
# Enter a string Welcome
# c

# %%
s = input('Enter a string')[3:]
print(s)
# Out:
# Enter a string 23421455653435464
# 21455653435464

# %%
s = (input('Enter a string'))
print(s)
# Out:
# Enter a string 12+10-0
# 12+10-0

# %%
s = int(input('Enter a string'))
print(s)
# Out:
# Enter a string 12+7-0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 s = int(input('Enter a string'))
#       2 print(s)
#
# ValueError: invalid literal for int() with base 10: '12+7-0'

# %%
s = eval(input('Enter a string'))
print(s)
# Out:
# Enter a string 12+10+1-20
# 3
